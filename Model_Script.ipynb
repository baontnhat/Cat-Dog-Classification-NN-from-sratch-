# %%
from Accuracy import *
from Activation import *
from Layer import *
from Loss import *
from Model import *
from Optimizer import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from sklearn.model_selection import train_test_split

# %%
def get_data():
    with open("data/X.pickle", "rb") as f:
        X = pickle.load(f)
    with open("data/y.pickle", "rb") as f:
        y = pickle.load(f)
    y = y.reshape(-1,1)
    X = X / 255
    X = X.reshape(X.shape[0], -1).astype(np.float32)
    return X, y

# %%
X, y = get_data()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size =0.25)

# %%
np.count_nonzero(y_train == 0)
# Out:
# 9355

# %%
np.count_nonzero(y_train == 1)
# Out:
# 9354

# %%
learning_rate = [0.001]
# learning_rate = [0.001]

# %%
model_lists = []
for lr in learning_rate:
    print(f"TRAINING MODEL USING LEARNING RATE {lr} ")
    model = Model()
    model.add(Layer_Dense(X_train.shape[1], 128))
    model.add(Activation_Sigmoid())
    model.add(Layer_Dense(128, 1))
    model.add(Activation_Sigmoid())

    model.set(loss=Loss_BinaryCrossentropy(),
              optimizer=Optimizer_Adam(learning_rate=lr, decay=1e-3),
              accuracy=Accuracy_Categorical(binary=True))
    model.finalize()
    model.train(X_train, y_train,  epochs=30, validation_data = (X_test, y_test), batch_size=128, print_every=100)
    model_lists.append(model)
# Out:
# TRAINING MODEL USING LEARNING RATE 0.001
# epoch: 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6896/75905315.py in <module>
#      12               accuracy=Accuracy_Categorical(binary=True))
#      13     model.finalize()
# ---> 14     model.train(X_train, y_train,  epochs=30, validation_data = (X_test, y_test), batch_size=128, print_every=100)
#      15     model_lists.append(model)
#
# c:\Users\ntnha\Downloads\AIL302m-main\Model.py in train(self, X, y, epochs, batch_size, print_every, validation_data)
#     127                 # Calculate loss
#     128                 data_loss, regularization_loss = \
# --> 129                     self.loss.calculate(output, batch_y,
#     130                                         include_regularization=False)
#     131                 loss = data_loss + regularization_loss
#
# c:\Users\ntnha\Downloads\AIL302m-main\Loss.py in calculate(self, output, y, include_regularization)
#      67
#      68         # Return the data and regularization losses
# ---> 69         return data_loss, self.regularization_loss()
#      70
#      71     # Calculates accumulated loss
#
# c:\Users\ntnha\Downloads\AIL302m-main\Loss.py in regularization_loss(self)
#      19             # L1 regularization - weights
#      20             # calculate only when factor greater than 0
# ---> 21             if layer.weight_regularizer_l1 > 0:
#      22                 regularization_loss += layer.weight_regularizer_l1 * \
#      23                                        np.sum(np.abs(layer.weights))
#
# AttributeError: 'Layer_Dense' object has no attribute 'weight_regularizer_l1'

# %%
best_model = model_lists[0]
PREDICT_LABEL = {0: "dog", 1: "cat"}
print(0.640)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6896/3834988144.py in <module>
# ----> 1 best_model = model_lists[0]
#       2 PREDICT_LABEL = {0: "dog", 1: "cat"}
#       3 print(0.640)
#
# NameError: name 'model_lists' is not defined

# %%
path = 'TestImg/cat1.jpg'
img=mpimg.imread(path)
imgplot=plt.imshow(img)
plt.show()
X = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (50, 50))
X = np.array(X)
X = X / 255
X = X.reshape(1, -1)
confidences = best_model.predict(X)
predictions = best_model.output_layer_activation.predictions(confidences)
predictions = predictions.reshape(-1)
predictions = int(predictions)
label = PREDICT_LABEL[predictions]
print(f"Prediction: {label}")
# Out:
# Prediction: cat

# %%
path = 'TestImg/cat2.jpg'
img=mpimg.imread(path)
imgplot=plt.imshow(img)
plt.show()
X = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (50, 50))
X = np.array(X)
X = X / 255
X = X.reshape(1, -1)
confidences = best_model.predict(X)
predictions = best_model.output_layer_activation.predictions(confidences)
predictions = predictions.reshape(-1)
predictions = int(predictions)
label = PREDICT_LABEL[predictions]
print(f"Prediction: {label}")
# Out:
# Prediction: cat

# %%
path = 'TestImg/cat3.jpg'
img=mpimg.imread(path)
imgplot=plt.imshow(img)
plt.show()
X = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (50, 50))
X = np.array(X)
X = X / 255
X = X.reshape(1, -1)
confidences = best_model.predict(X)
predictions = best_model.output_layer_activation.predictions(confidences)
predictions = predictions.reshape(-1)
predictions = int(predictions)
label = PREDICT_LABEL[predictions]
print(f"Prediction: {label}")
# Out:
# Prediction: dog

# %%
path = 'TestImg/dog2.jpg'
img=mpimg.imread(path)
imgplot=plt.imshow(img)
plt.show()
X = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (50, 50))
X = np.array(X)
X = X / 255
X = X.reshape(1, -1)
confidences = best_model.predict(X)
predictions = best_model.output_layer_activation.predictions(confidences)
predictions = predictions.reshape(-1)
predictions = int(predictions)
label = PREDICT_LABEL[predictions]
print(f"Prediction: {label}")
# Out:
# Prediction: dog

# %%
path = 'TestImg/dog1.jpg'
img=mpimg.imread(path)
imgplot=plt.imshow(img)
plt.show()
X = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (50, 50))
X = np.array(X)
X = X / 255
X = X.reshape(1, -1)
confidences = best_model.predict(X)
predictions = best_model.output_layer_activation.predictions(confidences)
predictions = predictions.reshape(-1)
predictions = int(predictions)
label = PREDICT_LABEL[predictions]
print(f"Prediction: {label}")
# Out:
# Prediction: dog

# %%
path = 'TestImg/dog4.jpg'
img=mpimg.imread(path)
imgplot=plt.imshow(img)
plt.show()
X = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (50, 50))
X = np.array(X)
X = X / 255
X = X.reshape(1, -1)
confidences = best_model.predict(X)
predictions = best_model.output_layer_activation.predictions(confidences)
predictions = predictions.reshape(-1)
predictions = int(predictions)
label = PREDICT_LABEL[predictions]
print(f"Prediction: {label}")
# Out:
# Prediction: cat

# %%
path = 'TestImg/dog7.jpg'
img=mpimg.imread(path)
imgplot=plt.imshow(img)
plt.show()
X = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (50, 50))
X = np.array(X)
X = X / 255
X = X.reshape(1, -1)
confidences = best_model.predict(X)
predictions = best_model.output_layer_activation.predictions(confidences)
predictions = predictions.reshape(-1)
predictions = int(predictions)
label = PREDICT_LABEL[predictions]
print(f"Prediction: {label}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16828/1183841188.py in <module>
#       1 path = 'TestImg/dog7.jpg'
# ----> 2 img=mpimg.imread(path)
#       3 imgplot=plt.imshow(img)
#       4 plt.show()
#       5 X = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (50, 50))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1499                     response = io.BytesIO(response.read())
#    1500                 return imread(response, format=ext)
# -> 1501     with img_open(fname) as image:
#    1502         return (_pil_png_to_float_array(image)
#    1503                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TestImg/dog7.jpg'
