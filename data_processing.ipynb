# %%
import pickle, random, os, cv2
import numpy as np
from tqdm import tqdm

DATA_DIR = "D:\\FPT_project\\AILm\\Project\\Data\\PetImages"
CATEGORIES = ["Dog", "Cat"]
IMG_SIZE = 50

# %%
def create_data():
    training_data = []
    for category in CATEGORIES:
        path = os.path.join(DATA_DIR, category)  # Create path to file
        class_num = CATEGORIES.index(category)  # get the classification 0 is dog, 1 is cat

        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)  # convert image to gray scale
                img_array_resize = cv2.resize(img_array, (50, 50))
                training_data.append([img_array_resize, class_num])
            except Exception as e:
                print(f"Error at {os.path.join(path, img)}"
                      f"\n"
                      f"Detail: {e}")
    
    return training_data

# %%
def save_data(training_data, path_X, path_y):
    X = []
    y = []
    for feature, label in training_data:
        X.append(feature)
        y.append(label)
    X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    y = np.array(y)
    pickle_out = open(path_X, "wb")
    pickle.dump(X, pickle_out)
    pickle_out.close()
    pickle_out = open(path_y, "wb")
    pickle.dump(y, pickle_out)
    pickle_out.close()

# %%
def train_test_split(X, y):
    size = len(X)
    train_size = 0.7 * size
    X_train, y_train = X[:train_size], y[train_size]
    X_test, y_test = X[train_size:], y[train_size:]
    return X_train, y_train, X_test, y_test

# %%
path_X_train = "data/X_train.pickle"
path_y_train = "data/y_train.pickle"
path_X_test = "data/X_test.pickle"
path_y_test = "data/y_test.pickle"

# %%
training_data = create_data()
# Out:
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\10158.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\10401.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\10747.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\10797.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\11410.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\11675.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\11702.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\11849.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\11853.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\1308.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\1866.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\2384.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\2688.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\2877.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\3136.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\3288.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\3588.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\4367.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\5604.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\5736.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\6059.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\6238.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\6718.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\7112.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\7133.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\7369.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\7459.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\7969.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\8730.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\9188.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Dog\Thumbs.db
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\10125.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\10404.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\10501.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\10820.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\11210.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\11565.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\11874.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\11935.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\140.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\2663.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\3300.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\3491.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\4833.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\5553.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\660.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\666.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\7968.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\7978.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\8470.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\850.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\9171.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\936.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\9565.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\9778.jpg
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error at D:\FPT_project\AILm\Project\Data\PetImages\Cat\Thumbs.db
# Detail: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
training_data
# Out:
# [[array([[115, 160, 159, ..., 157, 148, 139],
#          [121, 164, 166, ..., 163, 153, 146],
#          [124, 161, 164, ..., 168, 161, 151],
#          ...,
#          [155, 128,  88, ...,  81,  69,  68],
#          [ 87,  95,  72, ...,  77,  74,  73],
#          [ 75,  78,  79, ...,  75,  78,  75]], dtype=uint8),
#   0],
#  [array([[116, 125,  75, ...,  88,  81,  61],
#          [ 83, 126,  82, ...,  93,  69,  58],
#          [106, 117,  99, ...,  27,  88,  68],
#          ...,
#          [245, 243, 249, ..., 231, 224, 216],
#          [249, 246, 249, ..., 238, 227, 227],
#          [240, 239, 243, ..., 243, 234, 234]], dtype=uint8),
#   0],
#  [array([[112, 102, 116, ..., 123, 122, 123],
#          [ 88, 110, 120, ..., 123, 121, 119],
#          [138, 140, 126, ..., 124, 124, 125],
#          ...,
#          [203, 208, 206, ...,  98,  96,  94],
#          [201, 199, 197, ...,  92,  95,  96],
#          [201, 199, 198, ...,  93,  96,  95]], dtype=uint8),
#   0],
#  [array([[188, 184, 181, ...,  35,  32,  38],
#          [181, 184, 183, ...,  59,  26,  35],
#          [182, 184, 184, ...,  39,  55,  25],
#          ...,
#          [174, 174, 171, ...,  75,  62,  55],
#          [139, 167, 172, ...,  69,  67,  65],
#          [167, 152, 157, ...,  70,  69,  66]], dtype=uint8),
#   0],
#  [array([[ 16,  10,  44, ...,  21, 157, 170],
#          [ 73,  72,  68, ...,  20, 159, 166],
#          [ 92,  96,  86, ..., 100,  92, 137],
#          ...,
#          [108, 107, 105, ..., 114, 110, 108],
#          [102, 107, 106, ..., 126, 110, 109],
#          [105,  99, 104, ..., 124, 120, 117]], dtype=uint8),
#   0],
#  [array([[246, 229, 228, ..., 125, 121, 124],
#          [243, 231, 240, ..., 132, 117, 121],
#          [241, 229, 228, ..., 130, 143, 127],
#          ...,
#          [254, 254, 254, ...,  82, 104,  86],
#          [254, 254, 254, ...,  84, 103,  86],
#          [254, 254, 254, ...,  89,  86,  93]], dtype=uint8),
#   0],
#  [array([[ 16,  52,  94, ...,  39,  42,  55],
#          [ 12,   3, 136, ...,  28,  24,  39],
#          [ 17,   8, 159, ...,  34,  22,  29],
#          ...,
#          [ 26,  26,  27, ..., 128, 127, 126],
#          [ 12,  12,  13, ..., 119, 119, 125],
#          [  3,   4,   6, ..., 127, 125, 126]], dtype=uint8),
#   0],
#  [array([[119, 126, 126, ...,  34,  53,  50],
#          [120, 124, 130, ...,  58,  52,  50],
#          [130, 120, 126, ...,  56,  52,  50],
#          ...,
#          [ 64,  54,  73, ...,  57,  60,  52],
#          [ 63,  66,  70, ...,  63,  55,  53],
#          [ 66,  61,  73, ...,  59,  52,  57]], dtype=uint8),
#   0],
#  [array([[ 60,  79,  96, ..., 170, 185, 171],
#          [ 87,  79,  89, ..., 213, 179, 222],
#          [101,  79,  80, ..., 158, 175, 235],
#          ...,
#          [237, 252, 248, ...,  51,  52, 104],
#          [251, 234, 189, ...,  98, 113,  52],
#          [229, 207, 116, ..., 113,  98,  85]], dtype=uint8),
#   0],
#  [array([[236, 236, 237, ..., 197, 196, 193],
#          [237, 237, 228, ..., 200, 199, 197],
#          [236, 238, 226, ..., 203, 200, 200],
#          ...,
#          [149, 144, 132, ..., 133,  90, 116],
#          [136, 144, 141, ...,  67,  80, 127],
#          [127, 122, 151, ...,  38,  58,  93]], dtype=uint8),
#   0],
#  [array([[ 26,  15,  18, ...,   6,   6,   4],
#          [ 12,  13,  12, ...,  19,  10,   3],
#          [ 17,  15,  14, ...,  17,  16,   5],
#          ...,
#          [103, 110, 107, ...,  53,  84,  71],
#          [ 75,  84,  92, ...,  82,  74,  71],
#          [106, 110, 106, ...,  80,  78,  64]], dtype=uint8),
#   0],
#  [array([[  5,   6,   5, ...,   5,   6,   5],
#          [  5,   6,   5, ...,   5,   5,   3],
#          [  5,   5,   5, ...,   5,   5,   3],
#          ...,
#          [ 22,  22,  22, ...,  87,  39,  17],
#          [ 20,  24,  23, ..., 102,  82,  17],
#          [ 22,  22,  21, ..., 113,  72,  18]], dtype=uint8),
#   0],
#  [array([[122,  78,  76, ..., 242, 247, 253],
#          [213,  86,  82, ..., 248, 245, 247],
#          [241, 132,  85, ..., 255, 254, 251],
#          ...,
#          [ 19,  13,  14, ..., 220, 227, 250],
#          [ 19,  14,  14, ..., 236, 226, 238],
#          [ 22,  15,  14, ..., 231, 203, 215]], dtype=uint8),
#   0],
#  [array([[  2,   5,   3, ...,  14, 121,  40],
#          [  4,   3,   3, ...,   2, 128, 119],
#          [  3,   3,   3, ...,   2, 120,  34],
#          ...,
#          [132,  96,  89, ..., 164, 114, 148],
#          [ 69,  98,  39, ..., 148, 121, 117],
#          [ 83,  31,  48, ...,  89, 112, 131]], dtype=uint8),
#   0],
#  [array([[119, 127, 132, ..., 219, 220, 222],
#          [128, 130, 133, ..., 217, 221, 226],
#          [129, 129, 132, ..., 219, 225, 222],
#          ...,
#          [131, 167, 162, ..., 144, 145, 143],
#          [129, 167, 167, ..., 132, 128, 124],
#          [158, 161, 166, ..., 133, 129, 129]], dtype=uint8),
#   0],
#  [array([[127, 110, 109, ..., 110, 108, 124],
#          [125, 107, 106, ..., 104, 105, 122],
#          [124, 105, 104, ..., 107, 107, 121],
#          ...,
#          [145, 135, 133, ..., 129, 116, 126],
#          [152, 146, 131, ..., 111, 106, 133],
#          [136, 140, 133, ..., 137, 149, 155]], dtype=uint8),
#   0],
#  [array([[109,  80, 248, ...,  51,  57,  57],
#          [162, 238, 233, ...,  63,  56,  56],
#          [229, 234, 239, ...,  54,  62,  60],
#          ...,
#          [101,  99, 100, ...,  89,  91,  95],
#          [100, 105,  73, ...,  82,  93,  97],
#          [ 87, 100, 104, ...,  97,  87, 108]], dtype=uint8),
#   0],
#  [array([[126, 154, 103, ..., 202, 125,  59],
#          [137, 116, 122, ..., 143, 158, 152],
#          [154,  97, 100, ..., 189, 141, 123],
#          ...,
#          [183,  98, 199, ...,  50,  50,  55],
#          [ 38, 183, 157, ...,  51,  50,  52],
#          [160, 210, 202, ...,  54,  59,  54]], dtype=uint8),
#   0],
#  [array([[64, 75, 64, ..., 56, 53, 64],
#          [70, 76, 83, ..., 62, 62, 67],
#          [57, 72, 40, ..., 65, 57, 80],
#          ...,
#          [41, 46, 36, ..., 60, 64, 56],
#          [52, 76, 55, ..., 74, 63, 41],
#          [64, 32, 41, ..., 48, 34, 56]], dtype=uint8),
#   0],
#  [array([[  9,  16,  16, ...,  71,  70,  70],
#          [ 11,  19,  29, ...,  50,  46,  58],
#          [ 29,  30,  34, ...,  86,  84,  63],
#          ...,
#          [133, 140, 125, ..., 112, 105,  96],
#          [128, 140, 138, ...,  19,  26,  97],
#          [127, 133, 136, ...,  19,  14,  21]], dtype=uint8),
#   0],
#  [array([[ 67, 121,  73, ..., 105,  81, 150],
#          [ 59, 105,  76, ..., 150, 183, 179],
#          [120,  95,  91, ...,  79, 142, 121],
#          ...,
#          [137, 128, 134, ..., 170, 172, 173],
#          [133, 138, 144, ..., 166, 168, 165],
#          [134, 145, 139, ..., 168, 167, 162]], dtype=uint8),
#   0],
#  [array([[ 13,  64,  21, ..., 125, 165, 132],
#          [ 23,  22,  23, ..., 181, 122, 116],
#          [ 12,  19,   2, ..., 154, 131, 132],
#          ...,
#          [ 19,  25,  25, ...,  68,  69,  39],
#          [ 15,  48,  85, ...,  80,  39,  64],
#          [ 76, 100, 110, ...,  91,  63,  78]], dtype=uint8),
#   0],
#  [array([[ 30,  46,  70, ...,  92,  85,  84],
#          [ 30,  30,  99, ...,  86,  84,  87],
#          [ 30,  32, 103, ...,  84,  87,  80],
#          ...,
#          [115, 103, 111, ..., 162, 149, 132],
#          [ 97, 110, 121, ..., 161, 142, 129],
#          [100, 113, 116, ..., 149, 146, 126]], dtype=uint8),
#   0],
#  [array([[156, 138, 148, ..., 119,  71,  71],
#          [146, 141, 152, ...,  61,  68,  72],
#          [138, 144, 158, ...,  81,  46,  46],
#          ...,
#          [140, 169, 154, ..., 191, 178, 181],
#          [164, 167, 161, ..., 193, 187, 178],
#          [140, 154, 154, ..., 183, 180, 183]], dtype=uint8),
#   0],
#  [array([[145, 149, 118, ..., 145, 148, 140],
#          [158, 153, 127, ..., 155, 149, 147],
#          [156, 160, 117, ..., 151, 153, 140],
#          ...,
#          [ 96,  93, 108, ..., 108, 100,  98],
#          [152, 130, 126, ..., 100, 107,  98],
#          [ 83,  99, 132, ...,  74,  98,  99]], dtype=uint8),
#   0],
#  [array([[152, 160, 165, ..., 150, 140, 157],
#          [156, 160, 154, ..., 163, 150, 146],
#          [156, 160, 160, ..., 156, 159,  84],
#          ...,
#          [ 32, 119,  22, ..., 167,  96,  89],
#          [147,  29,  17, ..., 112, 128,  78],
#          [ 94,  28,  13, ..., 108, 106,  92]], dtype=uint8),
#   0],
#  [array([[145, 128, 121, ..., 182, 183, 187],
#          [144, 125, 125, ..., 184, 187, 191],
#          [141, 130, 147, ..., 185, 189, 191],
#          ...,
#          [187, 189, 190, ..., 148, 151, 153],
#          [185, 187, 188, ..., 145, 147, 149],
#          [183, 185, 186, ..., 140, 143, 145]], dtype=uint8),
#   0],
#  [array([[ 59,  35,  44, ..., 125, 126, 125],
#          [ 71,  47,  45, ..., 129, 128, 129],
#          [ 54,  38,  39, ..., 127, 128, 129],
#          ...,
#          [154, 118, 147, ..., 117, 123, 120],
#          [153, 129, 134, ..., 113, 120, 114],
#          [128, 101, 117, ..., 128, 131, 123]], dtype=uint8),
#   0],
#  [array([[246, 248, 245, ..., 122, 125, 125],
#          [172, 129, 179, ..., 122, 122, 136],
#          [167, 110, 151, ..., 131, 157, 152],
#          ...,
#          [130, 134, 114, ..., 165, 151, 134],
#          [162, 192, 177, ..., 151, 149, 158],
#          [129, 147, 152, ..., 129, 162, 142]], dtype=uint8),
#   0],
#  [array([[ 37,  15,  32, ..., 152, 149, 136],
#          [ 47,  32,  22, ..., 152, 142, 125],
#          [ 70,   7,  15, ..., 156, 137, 115],
#          ...,
#          [ 98, 101, 109, ..., 128, 114, 118],
#          [ 89, 100,  89, ..., 121, 106, 117],
#          [ 99,  97, 104, ...,  99, 118, 111]], dtype=uint8),
#   0],
#  [array([[109, 122, 125, ..., 115, 107, 110],
#          [115, 119, 122, ..., 116, 112, 111],
#          [116, 124, 126, ..., 121, 114, 110],
#          ...,
#          [ 23,  21,   9, ..., 235, 244, 241],
#          [ 15,  19,  14, ..., 233, 236, 238],
#          [ 16,   8,   8, ..., 235, 232, 235]], dtype=uint8),
#   0],
#  [array([[ 50,  55,  57, ...,   3,  49,  52],
#          [ 55,  59,  61, ...,   2,  48,  58],
#          [ 58,  63,  65, ...,   2,  48,  62],
#          ...,
#          [142, 148, 223, ..., 180, 189, 200],
#          [167, 209, 220, ..., 109, 105, 159],
#          [104, 184, 170, ...,  94, 105, 153]], dtype=uint8),
#   0],
#  [array([[175, 176, 176, ...,  71,  72,  48],
#          [176, 177, 178, ...,  74,  72,  48],
#          [176, 180, 182, ...,  77,  71,  45],
#          ...,
#          [112, 116, 117, ..., 120, 117, 116],
#          [112, 116, 120, ..., 121, 117, 116],
#          [112, 116, 118, ..., 124, 121, 122]], dtype=uint8),
#   0],
#  [array([[146, 104, 150, ..., 173, 209, 178],
#          [123, 142, 171, ..., 174, 168, 225],
#          [147, 142, 174, ..., 217, 131, 209],
#          ...,
#          [ 89, 153,  60, ...,  65,  98, 126],
#          [ 97,  79,  96, ...,  92, 106,  76],
#          [150, 153, 104, ..., 105,  95,  84]], dtype=uint8),
#   0],
#  [array([[ 94,  92,  84, ...,  56,  91,  91],
#          [ 93,  95,  84, ...,  53,  89,  92],
#          [ 93,  95,  88, ...,  41,  89,  94],
#          ...,
#          [ 75,  81,  86, ..., 164, 146, 198],
#          [ 74,  77,  90, ..., 118, 184, 199],
#          [ 78, 190, 214, ..., 113, 192, 197]], dtype=uint8),
#   0],
#  [array([[83, 65, 52, ..., 75, 54, 63],
#          [74, 69, 64, ..., 64, 70, 67],
#          [61, 74, 58, ..., 74, 65, 87],
#          ...,
#          [42, 45, 76, ..., 64, 51, 43],
#          [78, 42, 85, ..., 77, 69, 51],
#          [43, 52, 34, ..., 58, 48, 18]], dtype=uint8),
#   0],
#  [array([[254, 254, 254, ..., 254, 254, 254],
#          [254, 254, 254, ..., 254, 254, 254],
#          [254, 254, 254, ..., 254, 254, 254],
#          ...,
#          [254, 254, 254, ..., 254, 254, 254],
#          [254, 254, 254, ..., 254, 254, 254],
#          [254, 254, 254, ..., 254, 254, 254]], dtype=uint8),
#   0],
#  [array([[139, 164, 165, ...,  86,  68,  77],
#          [141, 165, 165, ...,  83,  67,  79],
#          [140, 164, 165, ...,  83,  63,  78],
#          ...,
#          [ 97,  95,  87, ..., 131, 132, 125],
#          [ 88,  89,  91, ..., 133, 134, 127],
#          [ 83,  83,  89, ..., 133, 128, 126]], dtype=uint8),
#   0],
#  [array([[ 34, 108, 178, ..., 124,  63,  49],
#          [ 26,  24,  34, ...,  64,  23,  72],
#          [ 27,  25,  21, ...,  38,  57,  68],
#          ...,
#          [140, 138, 137, ...,  94,  80,  25],
#          [138, 137,  81, ..., 142,  84,  52],
#          [137, 107, 143, ..., 186, 145, 190]], dtype=uint8),
#   0],
#  [array([[180, 141, 148, ..., 172, 149,  61],
#          [133, 187, 211, ..., 207, 191, 211],
#          [153, 194, 225, ..., 136, 126, 158],
#          ...,
#          [110, 184,  48, ..., 140, 114, 126],
#          [219, 109, 138, ..., 113, 101, 108],
#          [153, 224, 137, ..., 139, 174, 127]], dtype=uint8),
#   0],
#  [array([[145, 168, 173, ..., 158,  96, 164],
#          [130, 165, 178, ..., 138, 160, 140],
#          [151, 112, 156, ..., 204, 158, 154],
#          ...,
#          [186, 143, 156, ..., 182, 172, 142],
#          [146, 129,  77, ..., 163, 170, 164],
#          [147, 137, 127, ..., 170, 145, 169]], dtype=uint8),
#   0],
#  [array([[ 34,  31,  31, ...,  31,  31,  36],
#          [ 30, 253, 250, ..., 250, 251,  31],
#          [ 30, 250, 250, ..., 250, 250,  32],
#          ...,
#          [ 30, 250, 250, ..., 250, 250,  32],
#          [ 29, 248, 251, ..., 251, 249,  31],
#          [ 43,  41,  41, ...,  41,  41,  45]], dtype=uint8),
#   0],
#  [array([[155, 158, 158, ..., 208, 220, 218],
#          [158, 158, 158, ..., 203, 220, 230],
#          [158, 158, 158, ..., 212, 206, 215],
#          ...,
#          [193, 189, 187, ..., 209, 210, 205],
#          [186, 188, 191, ..., 206, 209, 209],
#          [202, 193, 198, ..., 208, 209, 207]], dtype=uint8),
#   0],
#  [array([[247, 250, 252, ..., 222, 241, 240],
#          [165, 136,  99, ..., 167, 242, 238],
#          [100,  52,  71, ..., 245, 243, 211],
#          ...,
#          [157, 144, 155, ..., 119, 109,  89],
#          [158, 147, 149, ..., 132, 103, 117],
#          [105, 120, 165, ..., 129, 132, 109]], dtype=uint8),
#   0],
#  [array([[ 22,  82, 110, ...,  75,  28,  96],
#          [102,  79,  69, ..., 132, 155, 101],
#          [126,  76,  88, ...,  87,  21, 117],
#          ...,
#          [107,  88, 111, ..., 121,  93,  81],
#          [ 98, 138,  91, ..., 118,  60, 134],
#          [ 54,  89, 137, ..., 123, 116,  60]], dtype=uint8),
#   0],
#  [array([[159, 172, 170, ..., 169, 167, 167],
#          [167, 157, 168, ..., 172, 170, 169],
#          [170, 169, 153, ..., 161, 171, 172],
#          ...,
#          [153, 149, 157, ..., 163, 155, 155],
#          [161, 178, 154, ..., 152, 162, 156],
#          [157, 163, 155, ..., 162, 163, 151]], dtype=uint8),
#   0],
#  [array([[ 67,  55,  58, ...,  35, 118,  49],
#          [156,  49,  57, ...,  52, 113,  48],
#          [ 69, 125,  75, ..., 104,  44, 112],
#          ...,
#          [143, 143, 148, ..., 255, 255, 255],
#          [152, 148, 158, ..., 255, 255, 255],
#          [137, 168, 144, ..., 255, 255, 255]], dtype=uint8),
#   0],
#  [array([[  7,  17,  10, ..., 135, 151, 132],
#          [ 10,   9,   9, ..., 185, 122, 124],
#          [ 63,  13,   8, ..., 208, 154, 128],
#          ...,
#          [ 73, 102, 106, ...,  68, 156, 127],
#          [ 70,  83,  79, ..., 168, 165,  82],
#          [ 67,  72,  85, ..., 140,  59, 119]], dtype=uint8),
#   0],
#  [array([[54, 52, 53, ..., 55, 51, 52],
#          [55, 56, 54, ..., 57, 55, 54],
#          [57, 55, 56, ..., 56, 58, 57],
#          ...,
#          [85, 85, 85, ..., 85, 80, 82],
#          [79, 82, 83, ..., 85, 89, 83],
#          [81, 81, 80, ..., 84, 91, 81]], dtype=uint8),
#   0],
#  [array([[118, 112, 126, ...,  98, 105, 102],
#          [121, 134, 128, ...,  86, 101,  86],
#          [118, 137, 121, ..., 105,  92, 101],
#          ...,
#          [179, 184, 202, ..., 198, 145, 192],
#          [200, 187, 198, ..., 186, 194, 202],
#          [246, 250, 249, ..., 198, 197, 179]], dtype=uint8),
#   0],
#  [array([[124,  64, 130, ...,  65,  77,  87],
#          [132,  64, 128, ...,  72,  83,  85],
#          [127,  66, 138, ...,  73,  84,  81],
#          ...,
#          [ 79,  78,  72, ...,  64,  64,  60],
#          [ 65,  60,  61, ...,  69,  66,  62],
#          [ 56,  61,  59, ...,  59,  63,  62]], dtype=uint8),
#   0],
#  [array([[162, 158, 171, ..., 135, 138, 139],
#          [151, 151, 151, ..., 121, 119, 131],
#          [158, 135, 143, ..., 127, 127, 110],
#          ...,
#          [113, 116,  99, ..., 116, 128, 134],
#          [119, 105, 107, ..., 121, 102, 101],
#          [139, 100, 127, ...,  94,  93,  90]], dtype=uint8),
#   0],
#  [array([[ 12,  10,  13, ..., 123,  80, 109],
#          [  9,  10,  28, ..., 116, 109,  87],
#          [ 74,  50,  63, ..., 109, 100, 101],
#          ...,
#          [152, 190, 231, ..., 168, 125, 203],
#          [227, 235, 231, ..., 172, 196, 136],
#          [222, 236, 242, ..., 200, 177, 160]], dtype=uint8),
#   0],
#  [array([[164, 169, 162, ...,  31,  16,  17],
#          [159, 182, 205, ...,  49,   5,   7],
#          [156, 164, 210, ...,  64,  10,   8],
#          ...,
#          [ 21,  41,  52, ...,  85,  86,  93],
#          [ 12,  12,  12, ...,  90,  79,  88],
#          [ 10,  10,  15, ...,  87,  83,  86]], dtype=uint8),
#   0],
#  [array([[126, 119, 127, ..., 124, 135, 131],
#          [126, 121, 125, ..., 130, 118, 121],
#          [125, 122, 130, ..., 137, 121, 126],
#          ...,
#          [ 31,  41,  38, ..., 132, 137, 136],
#          [ 30,  31,  29, ..., 144, 146, 117],
#          [108,  65,  79, ..., 145, 145, 133]], dtype=uint8),
#   0],
#  [array([[132, 115, 107, ...,  91, 104, 105],
#          [125, 123, 123, ...,  90,  99, 109],
#          [118, 111, 134, ..., 108, 101, 103],
#          ...,
#          [138, 142, 125, ...,  67, 146,  79],
#          [143, 146, 109, ..., 103, 152,  62],
#          [100, 139, 132, ..., 161, 140,  94]], dtype=uint8),
#   0],
#  [array([[255, 251, 208, ..., 246, 254, 255],
#          [252, 203, 168, ..., 242, 247, 254],
#          [211, 171, 168, ..., 229, 243, 247],
#          ...,
#          [177, 162, 162, ..., 198, 179, 157],
#          [255, 148, 120, ..., 183, 186, 220],
#          [255, 255, 122, ..., 194, 225, 251]], dtype=uint8),
#   0],
#  [array([[ 72, 211, 246, ..., 154, 156, 168],
#          [110, 233, 246, ..., 142, 142, 153],
#          [135, 241, 245, ..., 150, 142, 152],
#          ...,
#          [ 89, 117, 136, ..., 105, 150, 116],
#          [102, 119, 144, ...,  66, 108,  72],
#          [110, 130, 152, ..., 124, 179, 130]], dtype=uint8),
#   0],
#  [array([[190, 249, 170, ..., 172, 154, 150],
#          [187, 249, 167, ..., 133, 136, 184],
#          [189, 250, 176, ..., 183, 207, 176],
#          ...,
#          [ 34,  87, 128, ..., 239, 245, 244],
#          [ 24,  59,  94, ..., 241, 243, 243],
#          [ 24,  45,  55, ..., 243, 244, 245]], dtype=uint8),
#   0],
#  [array([[108, 105, 110, ..., 128, 133, 123],
#          [101, 116, 104, ..., 127, 152, 140],
#          [ 90,  76,  74, ..., 148, 144, 147],
#          ...,
#          [ 68,  85,  88, ...,  64,  62,  53],
#          [ 97,  70, 108, ...,  75,  55,  54],
#          [ 93, 101,  95, ...,  41,  44,  56]], dtype=uint8),
#   0],
#  [array([[167, 173, 171, ..., 143, 143, 146],
#          [166, 171,  76, ..., 143, 145, 146],
#          [166, 170, 130, ..., 144, 145, 148],
#          ...,
#          [  8,  51,  89, ...,  74,  56,  44],
#          [ 14,  35,  99, ...,  47,  44,  44],
#          [ 37,  46,  31, ...,  46,  49,  44]], dtype=uint8),
#   0],
#  [array([[ 10,   6,   7, ...,  14,  14,  13],
#          [ 14,  12,  13, ...,  15,  15,  15],
#          [ 14,  22,  13, ...,  15,  16,  14],
#          ...,
#          [128, 121, 111, ...,  20,  22,  10],
#          [119, 111, 113, ...,  22,  25,  13],
#          [128, 118, 125, ...,  31,  20,  15]], dtype=uint8),
#   0],
#  [array([[174, 180, 182, ..., 184, 182, 176],
#          [178, 178, 183, ..., 190, 189, 182],
#          [179, 182, 183, ..., 192, 189, 185],
#          ...,
#          [149, 158, 151, ..., 166, 164, 160],
#          [163, 166, 166, ..., 164, 160, 160],
#          [152, 164, 163, ..., 162, 156, 152]], dtype=uint8),
#   0],
#  [array([[ 79,  59, 109, ..., 145, 130, 125],
#          [ 97, 139,  74, ..., 128, 129, 128],
#          [116, 106,  99, ..., 131, 128, 123],
#          ...,
#          [100, 104,  95, ...,  85,  92,  64],
#          [ 82,  64,  98, ..., 141,  83,  64],
#          [ 99,  93,  93, ..., 113,  84, 148]], dtype=uint8),
#   0],
#  [array([[161, 160, 158, ...,  65,  67,  63],
#          [169, 157, 149, ...,  60,  66,  46],
#          [157, 133, 139, ...,  68,  63,  41],
#          ...,
#          [139, 139, 153, ..., 133, 131, 131],
#          [133, 131, 141, ..., 129, 123, 131],
#          [131, 138, 138, ..., 129, 135, 131]], dtype=uint8),
#   0],
#  [array([[73, 78, 82, ..., 51, 47, 43],
#          [75, 81, 82, ..., 52, 48, 45],
#          [80, 82, 85, ..., 54, 50, 47],
#          ...,
#          [20, 24, 24, ..., 68, 67, 63],
#          [21, 19, 20, ..., 65, 63, 57],
#          [16, 17, 19, ..., 59, 58, 51]], dtype=uint8),
#   0],
#  [array([[169, 186, 190, ..., 225, 227, 229],
#          [125, 165, 186, ..., 220, 230, 227],
#          [118, 138, 164, ..., 229, 224, 227],
#          ...,
#          [179, 184, 182, ..., 185, 175, 159],
#          [178, 183, 178, ..., 186, 178,  62],
#          [183, 176, 168, ..., 181, 179, 173]], dtype=uint8),
#   0],
#  [array([[ 67,  71,  74, ...,  63, 141, 134],
#          [ 61,  55,  60, ...,  69, 147, 135],
#          [ 41,  33,  31, ...,  84, 148, 136],
#          ...,
#          [  2,   1,  14, ...,  43,  40,  40],
#          [  1,   1,  19, ...,  45,  42,  38],
#          [  1,   1,  21, ...,  46,  41,  38]], dtype=uint8),
#   0],
#  [array([[  6,  22,  25, ...,   4,   8,   1],
#          [ 13,  60, 119, ...,   0,   1,   1],
#          [ 19,  71, 115, ...,  26,   0,   1],
#          ...,
#          [ 25, 101, 165, ...,  70,  34,   9],
#          [  9,  41,  67, ...,  26,  16,   4],
#          [  2,   6,  10, ...,   4,   2,   1]], dtype=uint8),
#   0],
#  [array([[120, 122, 127, ...,  41,  33,  41],
#          [ 79,  66,  32, ...,  37,  22,  25],
#          [ 80,  70,  34, ...,  33,  19,  31],
#          ...,
#          [100, 127, 141, ..., 143, 152, 151],
#          [ 74, 108, 104, ..., 113, 118, 133],
#          [ 98, 164, 170, ..., 159, 160, 159]], dtype=uint8),
#   0],
#  [array([[ 5, 11, 25, ...,  0,  0,  4],
#          [ 8, 11, 20, ...,  2,  2, 26],
#          [10, 22, 19, ..., 24, 42, 48],
#          ...,
#          [72, 38, 67, ..., 91, 22, 15],
#          [65, 56, 56, ..., 74, 26, 16],
#          [72, 27, 43, ..., 94, 34, 18]], dtype=uint8),
#   0],
#  [array([[104, 104, 121, ...,  69,  73,  72],
#          [114, 106, 107, ...,  72,  72,  75],
#          [101, 112, 113, ...,  70,  75,  75],
#          ...,
#          [140, 122, 158, ..., 192, 195, 192],
#          [133, 144, 142, ..., 187, 188, 177],
#          [ 87, 138, 139, ..., 186, 178, 169]], dtype=uint8),
#   0],
#  [array([[ 48,  46,  53, ..., 104, 100,  86],
#          [ 44,  44,  49, ...,  97,  90,  81],
#          [ 44,  45,  48, ..., 103,  84,  80],
#          ...,
#          [128, 140, 159, ...,  54,  48,  44],
#          [132, 138,  88, ...,  52,  51,  48],
#          [ 61,  37,  29, ...,  54,  47,  45]], dtype=uint8),
#   0],
#  [array([[213, 217,  84, ..., 184, 182, 179],
#          [214, 217, 172, ..., 170, 172, 201],
#          [215, 179, 125, ..., 189, 185, 209],
#          ...,
#          [112, 109, 101, ..., 146, 140, 130],
#          [111, 107, 102, ..., 133, 135, 131],
#          [108, 106, 100, ..., 177, 177, 176]], dtype=uint8),
#   0],
#  [array([[124, 130, 123, ...,  57,  60,  62],
#          [117, 115, 119, ...,  59,  63,  60],
#          [139, 129, 130, ...,  52,  53,  56],
#          ...,
#          [138, 146, 139, ...,  77, 156,  84],
#          [139, 129, 129, ..., 107, 136,  98],
#          [140, 115, 125, ..., 116,  70,  88]], dtype=uint8),
#   0],
#  [array([[165, 163, 161, ...,  67,  35,  33],
#          [164, 163, 160, ...,  65,  36,  32],
#          [166, 163, 162, ...,  69,  35,  31],
#          ...,
#          [114,  72,  95, ...,  70,  80,  89],
#          [109, 102, 111, ...,  98,  70,  89],
#          [108, 101, 124, ...,  67, 116, 108]], dtype=uint8),
#   0],
#  [array([[ 44,  48,  42, ...,  30, 134, 134],
#          [ 43,  45,  48, ...,  63, 138, 141],
#          [ 34,  46,  48, ...,  23, 138, 141],
#          ...,
#          [ 46,  46,  48, ...,  19,   9,   5],
#          [ 47,  46,  46, ...,  17,   7,   5],
#          [ 42,  48,  46, ...,   2,   3,   3]], dtype=uint8),
#   0],
#  [array([[133, 160,  97, ..., 254, 254, 252],
#          [147, 151, 101, ..., 255, 231, 184],
#          [145, 157, 102, ..., 253, 253, 249],
#          ...,
#          [ 88,  91,  87, ..., 122, 103, 105],
#          [ 95,  89,  98, ..., 127, 121, 111],
#          [161, 155, 151, ..., 119, 117,  84]], dtype=uint8),
#   0],
#  [array([[176, 152, 173, ..., 169, 164, 171],
#          [165, 171, 166, ..., 155, 149, 144],
#          [162, 144, 171, ..., 141, 141, 130],
#          ...,
#          [106, 109, 157, ..., 133, 163, 124],
#          [129, 123, 161, ..., 159, 121, 123],
#          [ 89, 152, 162, ..., 160, 141, 164]], dtype=uint8),
#   0],
#  [array([[ 11,   0,  11, ...,  37,  17,  13],
#          [ 19,   4,  11, ...,  44,  35,  29],
#          [ 20,   1,   2, ...,  45,  13,  20],
#          ...,
#          [196, 176, 155, ..., 184, 199, 180],
#          [188, 132, 110, ..., 126, 113, 117],
#          [130, 168, 201, ..., 185, 162,  85]], dtype=uint8),
#   0],
#  [array([[106,  47,  71, ..., 116, 145, 156],
#          [110, 124,  90, ..., 105,  99, 152],
#          [ 70,  76,  95, ..., 166, 125, 139],
#          ...,
#          [142, 156, 128, ..., 213, 188, 119],
#          [ 66, 198, 205, ...,  97, 139,  97],
#          [155, 169, 158, ..., 148, 114, 109]], dtype=uint8),
#   0],
#  [array([[190,  46,  73, ..., 251, 251, 253],
#          [128,  83,  62, ..., 252, 252, 253],
#          [ 82, 195, 105, ..., 252, 252, 252],
#          ...,
#          [200, 183, 191, ..., 184, 182, 194],
#          [201, 188, 211, ..., 188, 195, 185],
#          [201, 208, 214, ..., 192, 193, 195]], dtype=uint8),
#   0],
#  [array([[151,  82,  70, ...,  40,  46,  46],
#          [ 80, 105, 101, ..., 147, 146, 106],
#          [ 75, 114, 114, ..., 138, 144, 129],
#          ...,
#          [184, 125, 186, ...,  17,  23,  17],
#          [ 96,  56, 134, ...,  22,  34,  18],
#          [112,  80,  38, ...,  19,  20,  17]], dtype=uint8),
#   0],
#  [array([[103, 111, 138, ..., 152, 161, 165],
#          [ 57,  81, 140, ..., 136,  98,  85],
#          [177, 185, 207, ..., 162, 166, 146],
#          ...,
#          [ 89, 111,  75, ..., 179, 136, 180],
#          [206,  63,  62, ..., 154, 132, 182],
#          [150,  96, 107, ...,  63, 113, 161]], dtype=uint8),
#   0],
#  [array([[186, 193, 198, ..., 217, 201, 215],
#          [192, 198, 201, ..., 126, 208, 152],
#          [195, 198, 203, ..., 218, 146, 141],
#          ...,
#          [181, 183, 184, ..., 118,  69,  71],
#          [176, 181, 183, ...,  77,  80,  60],
#          [236, 240, 239, ...,  84, 127,  68]], dtype=uint8),
#   0],
#  [array([[152, 132, 149, ...,  55,  71,  47],
#          [151, 139, 132, ...,  55,  67,  49],
#          [152, 140, 137, ...,  61,  62,  44],
#          ...,
#          [181, 168, 128, ..., 131, 135, 150],
#          [150, 133, 126, ..., 160, 151, 125],
#          [134, 144, 158, ..., 153, 134, 167]], dtype=uint8),
#   0],
#  [array([[122, 248, 222, ...,  70,  68,  68],
#          [119, 224, 246, ...,  69,  69,  64],
#          [139, 252, 252, ...,  73,  70,  68],
#          ...,
#          [ 92, 137, 197, ...,  24,  16,  63],
#          [ 83, 128, 201, ...,  17,  78,  26],
#          [ 51, 122, 182, ...,  69,  74,  59]], dtype=uint8),
#   0],
#  [array([[ 99,  81, 142, ..., 129, 109, 117],
#          [102, 109, 168, ..., 113, 111, 124],
#          [105, 118, 175, ..., 103, 132, 121],
#          ...,
#          [ 36,  62, 129, ...,  68,  44,  41],
#          [ 57,  75,  87, ...,  58,  61, 167],
#          [ 76,  58,  71, ..., 168, 171, 166]], dtype=uint8),
#   0],
#  [array([[ 43,  52,  58, ...,  89,  88,  36],
#          [ 59,  51,  58, ...,  87,  93,  99],
#          [ 50,  50,  56, ...,  79, 117,  78],
#          ...,
#          [ 14,  45,  49, ...,  25,  76,  97],
#          [ 33,  41,  51, ...,  95,  23,  83],
#          [ 28,  44,  35, ...,  98,  97,  16]], dtype=uint8),
#   0],
#  [array([[ 37,  41,  48, ..., 141, 128, 110],
#          [ 39,  46,  40, ..., 125, 126, 121],
#          [ 41,  43,  42, ..., 129, 132, 138],
#          ...,
#          [ 12,  15,  19, ..., 102, 107,  88],
#          [ 12,  13,  15, ..., 101, 112,  84],
#          [ 12,  12,  18, ..., 117, 118,  96]], dtype=uint8),
#   0],
#  [array([[ 53,  48,  43, ..., 180, 192, 183],
#          [ 50,  44,  36, ..., 179, 189, 186],
#          [ 52,  56,  48, ..., 194, 187, 186],
#          ...,
#          [ 60,  48,  54, ...,  44,  25,  27],
#          [ 58,  46,  45, ...,  37,  31,  29],
#          [ 55,  56,  43, ...,  35,  32,  37]], dtype=uint8),
#   0],
#  [array([[125, 123, 114, ..., 121, 109, 101],
#          [102, 106, 119, ..., 105, 114,  96],
#          [176, 184, 185, ..., 125, 108, 100],
#          ...,
#          [120, 138, 141, ...,  62, 110,  93],
#          [138, 132, 137, ...,  90, 114, 106],
#          [134, 135, 150, ..., 126, 110, 113]], dtype=uint8),
#   0],
#  [array([[221, 222, 220, ..., 136, 135, 134],
#          [220, 218, 216, ..., 136, 135, 133],
#          [219, 218, 222, ..., 136, 134, 135],
#          ...,
#          [175, 178, 160, ..., 160, 165, 161],
#          [180, 185, 170, ..., 159, 165, 162],
#          [177, 181, 176, ..., 159, 162, 163]], dtype=uint8),
#   0],
#  [array([[191, 191, 194, ...,  45,  46,  47],
#          [190, 193, 194, ...,  44,  44,  43],
#          [188, 192, 192, ...,  28,  54,  49],
#          ...,
#          [200, 200, 201, ..., 200, 200, 200],
#          [200, 201, 200, ..., 202, 200, 200],
#          [199, 200, 201, ..., 201, 203, 200]], dtype=uint8),
#   0],
#  [array([[213, 212, 213, ...,  77,  83,  52],
#          [174, 219, 214, ...,  58,  90,  70],
#          [211, 196, 202, ...,  73,  73,  57],
#          ...,
#          [175, 175, 177, ..., 131, 138, 132],
#          [180, 180, 181, ..., 180, 180, 181],
#          [ 52,  51,  47, ..., 197, 200, 209]], dtype=uint8),
#   0],
#  [array([[194, 205, 115, ..., 228, 237, 133],
#          [183, 199, 121, ..., 228, 137, 146],
#          [145, 167, 121, ..., 190, 207, 211],
#          ...,
#          [170, 181, 173, ..., 177, 188, 190],
#          [179, 182, 170, ..., 176, 186, 190],
#          [170, 169, 177, ..., 187, 192, 188]], dtype=uint8),
#   0],
#  [array([[155, 189, 181, ...,  75, 116, 128],
#          [175, 189, 181, ...,  90, 114, 118],
#          [181, 179, 180, ..., 191, 110, 138],
#          ...,
#          [161, 161, 152, ..., 170, 184, 175],
#          [164, 152, 151, ..., 170, 181, 144],
#          [159, 158, 165, ..., 148, 174, 167]], dtype=uint8),
#   0],
#  [array([[ 74,  74,  75, ..., 210, 203, 221],
#          [ 78,  79,  84, ..., 199, 210, 208],
#          [ 87,  88,  92, ..., 224, 231, 231],
#          ...,
#          [176, 217, 180, ..., 209, 244, 209],
#          [215, 192, 189, ..., 245, 239, 222],
#          [220, 206, 227, ..., 227, 233, 232]], dtype=uint8),
#   0],
#  [array([[164, 170, 165, ..., 200, 207, 211],
#          [164, 165, 164, ..., 209, 208, 215],
#          [182, 175, 177, ..., 196, 188, 206],
#          ...,
#          [174, 177, 174, ..., 170, 167, 171],
#          [168, 167, 176, ..., 168, 165, 167],
#          [167, 167, 166, ..., 168, 167, 171]], dtype=uint8),
#   0],
#  [array([[190, 186, 186, ...,  11,  19,  22],
#          [185, 185, 183, ...,   4,   3,   5],
#          [195, 180, 187, ...,  29,  31,  27],
#          ...,
#          [101,  94, 102, ..., 120, 124, 115],
#          [117, 116, 122, ..., 116, 118, 131],
#          [104, 116, 121, ..., 122, 113, 118]], dtype=uint8),
#   0],
#  [array([[123, 117, 109, ...,  60,  34,  40],
#          [120, 120, 110, ...,  43,  37,  18],
#          [123, 120, 110, ...,  63,  54,  30],
#          ...,
#          [137, 149, 143, ..., 201, 216, 176],
#          [147, 151, 143, ..., 220, 229, 204],
#          [151, 145, 148, ..., 214, 241, 225]], dtype=uint8),
#   0],
#  [array([[152, 133, 111, ..., 204, 204, 198],
#          [153, 144, 115, ..., 107,  84, 114],
#          [155, 150, 159, ...,  81,  71,  57],
#          ...,
#          [163, 117,  36, ..., 211, 210, 204],
#          [130, 117,  52, ..., 210, 208, 106],
#          [122, 116,  47, ..., 209, 208,  90]], dtype=uint8),
#   0],
#  [array([[157, 168, 177, ..., 142, 152, 155],
#          [158, 179, 179, ..., 151, 176, 156],
#          [148, 167, 158, ..., 158, 148, 143],
#          ...,
#          [154, 130, 140, ..., 166, 127, 114],
#          [147, 149, 156, ..., 178, 154, 138],
#          [187, 135, 139, ..., 157, 156, 157]], dtype=uint8),
#   0],
#  [array([[ 38,  37,  47, ...,  43,  54,  54],
#          [ 46,  44,  48, ...,  45,  51,  55],
#          [ 50,  51,  62, ...,  48,  57,  55],
#          ...,
#          [136, 173, 122, ...,  62,  34,  56],
#          [155, 176, 138, ...,  51,  27,  49],
#          [123, 125, 138, ...,  55,  32,  35]], dtype=uint8),
#   0],
#  [array([[ 94,  95,  94, ..., 226, 232, 227],
#          [ 97, 105, 115, ..., 230, 228, 230],
#          [103, 108,  96, ..., 211, 207, 217],
#          ...,
#          [ 94,  82,  82, ..., 231, 245, 230],
#          [ 75,  76,  73, ..., 253, 248, 247],
#          [ 64,  62,  77, ..., 251, 231, 231]], dtype=uint8),
#   0],
#  [array([[232, 188, 173, ..., 106, 253,  90],
#          [226, 151, 167, ..., 107, 254,  61],
#          [248, 209, 171, ..., 106, 196,  54],
#          ...,
#          [118, 109, 115, ...,  30,  20,  38],
#          [110, 105, 100, ...,  26,  21,  28],
#          [ 99, 106,  95, ...,  87,  57,  45]], dtype=uint8),
#   0],
#  [array([[113, 116, 125, ..., 142, 126, 167],
#          [ 83,  94, 119, ..., 133, 120, 172],
#          [ 96,  99, 118, ..., 125, 109, 170],
#          ...,
#          [133, 139, 121, ..., 158, 164, 159],
#          [113, 163, 131, ..., 148, 141, 140],
#          [128, 148, 123, ..., 137, 159, 135]], dtype=uint8),
#   0],
#  [array([[171, 199, 199, ..., 146, 190, 218],
#          [123, 132, 122, ..., 144, 191, 223],
#          [ 72,  45,  31, ..., 141, 187, 212],
#          ...,
#          [ 78, 121, 151, ...,  25,  31,  40],
#          [ 79, 119, 154, ...,  27,  31,  42],
#          [ 75, 118, 153, ...,  29,  32,  43]], dtype=uint8),
#   0],
#  [array([[104,  87, 109, ..., 120, 104, 118],
#          [119, 115, 110, ..., 122, 101,  80],
#          [ 81, 123, 133, ..., 118,  93,  88],
#          ...,
#          [119, 125, 144, ..., 115, 112, 110],
#          [123, 117, 141, ..., 106, 110, 100],
#          [115, 127, 137, ..., 111,  95, 104]], dtype=uint8),
#   0],
#  [array([[ 97,  97, 118, ..., 112, 116, 117],
#          [116,  96, 114, ..., 116, 113, 115],
#          [ 86,  93, 107, ..., 117, 118, 117],
#          ...,
#          [ 47,  51,  46, ...,  71,  52,   7],
#          [ 32,  64,  47, ...,  43,  17,   4],
#          [ 51,  44,  30, ...,  33,  11,  43]], dtype=uint8),
#   0],
#  [array([[232, 233, 233, ..., 243, 241, 241],
#          [232, 233, 234, ..., 242, 242, 240],
#          [231, 233, 235, ..., 243, 243, 241],
#          ...,
#          [ 95,  99,  99, ...,  90,  91,  91],
#          [101, 102,  97, ...,  91,  90,  91],
#          [ 99, 100,  90, ...,  95,  88,  93]], dtype=uint8),
#   0],
#  [array([[ 63,  66,  72, ...,  42,  42,  39],
#          [ 75,  71,  64, ...,  66,  39,  69],
#          [ 64,  88,  63, ...,  48,  51,  56],
#          ...,
#          [ 93, 101,  66, ...,  35,  30,  28],
#          [ 96,  74,  74, ...,  13,  26,  23],
#          [100,  70,  65, ...,  19,  35,  37]], dtype=uint8),
#   0],
#  [array([[163, 173, 165, ..., 103, 123,  89],
#          [150, 168, 170, ..., 119, 120, 103],
#          [139, 141, 164, ..., 125, 122, 104],
#          ...,
#          [215, 209, 196, ...,  84,  82,  57],
#          [213, 200, 202, ...,  98,  90,  41],
#          [191, 178, 212, ...,  84,  97,  40]], dtype=uint8),
#   0],
#  [array([[168, 172, 181, ..., 198, 183, 171],
#          [171, 176, 182, ..., 201, 193, 182],
#          [176, 178, 188, ..., 206, 196, 181],
#          ...,
#          [102, 102, 105, ..., 110,  98, 101],
#          [104, 100, 108, ...,  94,  97,  82],
#          [103, 105, 106, ...,  90,  93,  80]], dtype=uint8),
#   0],
#  [array([[255, 255, 237, ..., 214, 255, 255],
#          [255, 239, 195, ..., 142, 215, 255],
#          [241, 200, 159, ...,  74, 160, 222],
#          ...,
#          [230, 188, 161, ..., 148, 180, 229],
#          [255, 231, 189, ..., 180, 226, 255],
#          [255, 255, 231, ..., 225, 255, 255]], dtype=uint8),
#   0],
#  [array([[115,  99, 242, ..., 136, 174, 170],
#          [ 96, 108, 249, ..., 159, 168, 168],
#          [178, 132, 230, ..., 149, 164, 196],
#          ...,
#          [107, 101, 101, ...,  67,  81,  98],
#          [ 86, 100, 101, ...,  79,  88,  71],
#          [120, 117, 113, ..., 101,  71,  85]], dtype=uint8),
#   0],
#  [array([[150, 151, 154, ...,  57,  64,  35],
#          [151, 152, 149, ...,  47,  65,  35],
#          [151, 152, 151, ...,  33,  37,  37],
#          ...,
#          [133, 132, 131, ..., 109, 106, 112],
#          [128, 129, 130, ..., 129, 115, 114],
#          [128, 124, 139, ..., 115, 117, 125]], dtype=uint8),
#   0],
#  [array([[ 96, 144, 157, ..., 212, 215, 176],
#          [143, 135, 158, ..., 228, 204, 197],
#          [172, 117, 154, ..., 216, 218, 225],
#          ...,
#          [171, 169, 178, ..., 161, 152, 164],
#          [175, 175, 177, ..., 169, 167, 166],
#          [171, 173, 178, ..., 174, 173, 172]], dtype=uint8),
#   0],
#  [array([[134, 139, 142, ..., 175, 148, 120],
#          [134, 137, 142, ..., 175, 148, 136],
#          [134, 138, 143, ..., 173, 151, 155],
#          ...,
#          [108, 111, 114, ..., 126, 122, 116],
#          [110, 105, 113, ..., 130, 120, 118],
#          [102, 108, 109, ..., 126, 122, 118]], dtype=uint8),
#   0],
#  [array([[ 64, 110,  55, ...,  41,  23,  23],
#          [ 63,  96,  86, ...,  40,  30,  36],
#          [ 69,  77, 114, ...,  37,  51,  41],
#          ...,
#          [ 43,  65,  68, ...,  11,  24,  34],
#          [ 47,  59,  60, ...,  10,  23,  30],
#          [ 26,  38,  34, ...,  10,  23,  29]], dtype=uint8),
#   0],
#  [array([[ 11,  11,  34, ...,  61,  92,  76],
#          [ 27,  43,  54, ...,  75,  90,  77],
#          [ 23,  55,  35, ...,  71, 100,  82],
#          ...,
#          [ 78,  78,  38, ...,  51,  59,  74],
#          [ 76,  76,  36, ...,  51,  42,  82],
#          [ 68,  65,  20, ...,  50,  35,  46]], dtype=uint8),
#   0],
#  [array([[151, 142, 163, ...,  31,   7,   6],
#          [143, 153, 161, ...,  20,  27,   5],
#          [162, 145, 159, ...,  32,  15,   2],
#          ...,
#          [ 32,  14,  17, ...,  90,  93,  70],
#          [ 17,  16,  11, ...,  79,  63, 113],
#          [ 24,  40,  40, ...,  61,  67,  62]], dtype=uint8),
#   0],
#  [array([[ 97,  97,  98, ...,  45,  42,  38],
#          [117, 116, 110, ...,  32,  55,  43],
#          [134, 130,  67, ...,  17,  54,  24],
#          ...,
#          [ 89, 137, 123, ..., 133, 112, 117],
#          [129, 128, 128, ..., 142, 150, 112],
#          [132, 121, 125, ..., 139, 157,  94]], dtype=uint8),
#   0],
#  [array([[129,  95,  86, ..., 137, 118, 134],
#          [ 43,  42,  47, ..., 136, 139,  80],
#          [ 34,  28,  35, ...,  86,  87,  93],
#          ...,
#          [213, 251, 230, ..., 115,  90,  75],
#          [195, 231, 175, ...,  85,  68,  62],
#          [243, 211, 242, ...,  85,  70,  66]], dtype=uint8),
#   0],
#  [array([[158, 149, 158, ..., 202, 203, 197],
#          [152, 155, 164, ...,  32,  29,  34],
#          [142, 143, 160, ...,  30,  27,  29],
#          ...,
#          [169, 175, 167, ..., 143, 134, 132],
#          [170, 174, 176, ..., 142, 140, 140],
#          [176, 173, 177, ..., 151, 150, 147]], dtype=uint8),
#   0],
#  [array([[114, 108, 128, ...,  89, 124, 118],
#          [102, 141, 151, ..., 106, 102,  94],
#          [114, 115, 133, ...,  79, 102, 141],
#          ...,
#          [141, 112, 127, ..., 149, 122, 118],
#          [151, 124, 120, ..., 115, 110, 116],
#          [148, 167, 176, ..., 129, 163, 152]], dtype=uint8),
#   0],
#  [array([[ 42,  49,  36, ...,  78, 121, 131],
#          [ 46,  43,  53, ..., 101,  89, 147],
#          [ 50,  34,  54, ..., 140, 110,  77],
#          ...,
#          [130, 178, 130, ..., 242, 182, 201],
#          [230,  83, 110, ..., 190, 103, 173],
#          [116,  83,  97, ..., 157, 125, 132]], dtype=uint8),
#   0],
#  [array([[159, 137, 129, ..., 147, 126, 123],
#          [131, 107, 129, ..., 137, 122, 100],
#          [ 90, 107,  90, ...,  90, 148, 126],
#          ...,
#          [154, 118, 122, ..., 103,  75,  84],
#          [110, 105,  67, ..., 124,  93,  98],
#          [109, 119, 106, ...,  89,  96,  76]], dtype=uint8),
#   0],
#  [array([[156, 156, 157, ...,  33,  48,  27],
#          [160, 156, 170, ...,  40,  51,  43],
#          [159, 155, 159, ...,  43,  39,  50],
#          ...,
#          [ 90,  58,  54, ..., 195, 158, 167],
#          [ 68,  45,  43, ..., 214, 201, 193],
#          [ 53,  31,  31, ..., 242, 206, 142]], dtype=uint8),
#   0],
#  [array([[ 33,  34,  37, ...,  23,  34,  37],
#          [ 31,  31,  26, ...,  30,  37,  39],
#          [ 36,  27,  26, ...,  29,  33,  28],
#          ...,
#          [218, 222, 224, ..., 194, 200, 180],
#          [217, 218, 221, ...,  90, 110, 138],
#          [ 99, 205, 215, ...,  50,  51,  53]], dtype=uint8),
#   0],
#  [array([[ 59,  51,  56, ...,  19,  13,  12],
#          [ 55,  53,  57, ...,  35,  28,  22],
#          [ 61,  52,  72, ...,  42,  44,  40],
#          ...,
#          [146, 129, 144, ...,  85,  61,  72],
#          [156, 146, 154, ...,  66,  65,  61],
#          [152, 150, 139, ...,  50,  65,  66]], dtype=uint8),
#   0],
#  [array([[ 73, 168, 185, ...,  14,  14,  48],
#          [ 92, 180, 183, ...,  13,  21,  45],
#          [ 82, 118, 179, ...,  44,  58,  66],
#          ...,
#          [101,  98,  87, ...,  85, 212, 180],
#          [ 89, 109, 121, ...,  90, 226, 186],
#          [ 71, 107, 105, ..., 100, 189, 184]], dtype=uint8),
#   0],
#  [array([[214, 215, 216, ..., 241, 239, 243],
#          [214, 215, 218, ..., 234, 236, 241],
#          [213, 213, 217, ..., 242, 243, 239],
#          ...,
#          [236, 241, 209, ..., 143, 146, 139],
#          [233, 230, 181, ..., 144, 143, 149],
#          [234, 230, 183, ..., 151, 146, 147]], dtype=uint8),
#   0],
#  [array([[ 69,  72,  79, ...,  52,  52,  51],
#          [ 31,  31,  29, ...,  46,  50,  51],
#          [ 35,  29,  30, ...,  37,  38,  38],
#          ...,
#          [ 81,  78,  77, ..., 189, 186, 179],
#          [ 83,  79,  66, ..., 200, 197, 189],
#          [ 83,  85,  84, ..., 204, 196, 171]], dtype=uint8),
#   0],
#  [array([[115, 160, 136, ..., 176, 206, 135],
#          [120, 123, 117, ..., 166, 203, 154],
#          [176, 157, 160, ..., 166, 198, 174],
#          ...,
#          [102, 127,  69, ...,  48,  67,  57],
#          [139,  68, 136, ...,  73,  72,  71],
#          [122, 104, 110, ...,  68,  68,  64]], dtype=uint8),
#   0],
#  [array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   0],
#  [array([[202, 205, 206, ..., 153, 148,  50],
#          [182, 199, 202, ..., 170, 149,  75],
#          [152, 201, 200, ..., 120, 135,  38],
#          ...,
#          [103, 102, 104, ..., 108, 105, 102],
#          [101, 105, 108, ..., 109, 102, 102],
#          [103, 107, 108, ..., 108, 108, 111]], dtype=uint8),
#   0],
#  [array([[ 25,  25,  23, ...,  65,  66,  77],
#          [ 35,  29,  23, ...,  94,  81,  80],
#          [ 78,  55,  36, ...,  97, 100,  98],
#          ...,
#          [ 83,  89, 165, ...,  16,  20,  22],
#          [ 84, 120, 179, ...,  21,  20,  17],
#          [ 90, 150, 163, ...,  22,  21,  20]], dtype=uint8),
#   0],
#  [array([[ 95, 118, 102, ..., 116, 119, 108],
#          [114, 105, 106, ..., 135, 127, 119],
#          [ 96, 123, 110, ..., 130, 140, 129],
#          ...,
#          [149, 151, 145, ..., 131, 127, 107],
#          [131, 129, 144, ..., 127, 114, 130],
#          [159, 129, 138, ..., 128, 116, 110]], dtype=uint8),
#   0],
#  [array([[122, 128, 109, ...,  17,  22,  14],
#          [119, 103, 141, ...,   6,   7,   5],
#          [124, 111, 129, ...,   6,   6,   6],
#          ...,
#          [ 72,  75,  97, ..., 253, 251, 239],
#          [ 97,  97,  95, ..., 255, 254, 227],
#          [ 98,  86,  91, ..., 254, 255, 225]], dtype=uint8),
#   0],
#  [array([[117, 145, 153, ..., 134, 118, 119],
#          [130, 103, 106, ..., 134, 136, 136],
#          [ 98, 131, 148, ..., 118, 132, 120],
#          ...,
#          [154, 163, 164, ..., 200, 178, 168],
#          [159, 145, 181, ..., 204, 175, 172],
#          [157, 164, 188, ..., 188, 177, 151]], dtype=uint8),
#   0],
#  [array([[ 38,  35,  61, ...,  28,  34,  27],
#          [ 25,  30,  68, ...,  46,  24,  29],
#          [ 34,  22,  36, ...,  74,  46,  32],
#          ...,
#          [143, 152,  77, ..., 207, 199, 202],
#          [ 43,  53,  79, ..., 204, 206, 201],
#          [ 44, 125, 113, ...,  48,  54,  50]], dtype=uint8),
#   0],
#  [array([[ 45,  63,  55, ...,  53,  56,  49],
#          [ 50,  63,  55, ...,  53,  55,  58],
#          [ 63,  64,  65, ...,  54,  58,  88],
#          ...,
#          [132, 140, 142, ..., 210, 144, 154],
#          [141, 137, 140, ..., 192, 148, 139],
#          [134, 143, 132, ..., 207, 179, 141]], dtype=uint8),
#   0],
#  [array([[144, 193, 195, ..., 176, 163, 148],
#          [160, 188, 116, ..., 174, 197, 135],
#          [166, 139, 159, ..., 160, 194, 155],
#          ...,
#          [ 56,  35,  37, ...,  38,  77,  97],
#          [ 62,  70,  50, ...,  54,  54,  54],
#          [ 59,  73,  68, ...,  58,  82, 103]], dtype=uint8),
#   0],
#  [array([[172, 170, 171, ...,  71,  71,  73],
#          [175, 177, 174, ...,  73,  72,  74],
#          [186, 178, 179, ...,  76,  76,  73],
#          ...,
#          [126, 125,  96, ..., 177, 183, 177],
#          [129, 116,  84, ..., 175, 179, 178],
#          [112,  92,  64, ..., 179, 178, 170]], dtype=uint8),
#   0],
#  [array([[ 97, 105, 121, ..., 126, 126, 121],
#          [102, 108, 125, ..., 123, 133, 123],
#          [101, 114, 118, ..., 119, 124, 116],
#          ...,
#          [117, 124, 117, ..., 108, 101,  96],
#          [122, 117, 118, ..., 108,  95, 104],
#          [107, 124, 125, ..., 100, 107,  96]], dtype=uint8),
#   0],
#  [array([[ 72,  79,  83, ...,  86,  88,  85],
#          [ 74,  88, 101, ..., 119,  86,  96],
#          [ 86,  90,  86, ...,  95,  86,  97],
#          ...,
#          [ 69,  65,  92, ..., 112,  86,  79],
#          [ 83,  73,  68, ...,  93, 101, 108],
#          [ 68,  90,  75, ...,  87,  91, 105]], dtype=uint8),
#   0],
#  [array([[254, 254, 122, ...,  33,  50,  60],
#          [243, 166, 156, ...,  39,  33,  32],
#          [145, 140, 141, ...,  66, 108,  49],
#          ...,
#          [227, 223, 224, ..., 124, 122, 121],
#          [215, 213, 222, ..., 122, 124, 116],
#          [ 90,  92,  96, ..., 122, 121, 117]], dtype=uint8),
#   0],
#  [array([[137, 148, 115, ..., 150,  96, 121],
#          [ 96, 127,  93, ..., 190, 155, 130],
#          [ 99, 166, 105, ..., 181, 101, 119],
#          ...,
#          [ 88,  66,  81, ..., 142, 112, 100],
#          [ 58,  68,  68, ...,  97, 105, 137],
#          [ 62,  36,  51, ..., 154, 127, 124]], dtype=uint8),
#   0],
#  [array([[162, 142, 115, ..., 138, 139, 135],
#          [108, 107, 108, ..., 134, 134, 133],
#          [129, 189, 247, ..., 217, 216, 220],
#          ...,
#          [ 84,  80,  74, ...,  77,  77,  92],
#          [ 81,  75,  75, ...,  79,  79,  92],
#          [ 80,  81,  79, ...,  84,  89,  92]], dtype=uint8),
#   0],
#  [array([[192, 192, 194, ...,  72,  92,  72],
#          [193, 188, 189, ...,  43,  87,  67],
#          [185, 189, 187, ...,  44,  80, 102],
#          ...,
#          [181, 177, 182, ..., 173, 178, 178],
#          [175, 179, 181, ..., 184, 182, 175],
#          [177, 176, 180, ..., 176, 184, 183]], dtype=uint8),
#   0],
#  [array([[176, 166, 176, ..., 190,  77,  73],
#          [172, 165, 166, ..., 195,  76,  75],
#          [126, 112, 167, ..., 200,  76,  72],
#          ...,
#          [ 43,  44,  47, ...,  50,  50,  56],
#          [ 61,  69,  66, ...,  51,  50,  49],
#          [ 68,  58,  57, ...,  46,  43,  48]], dtype=uint8),
#   0],
#  [array([[ 87,  86,  90, ..., 104, 105, 107],
#          [ 74,  72,  83, ..., 104, 106, 106],
#          [ 99, 100,  94, ...,  86,  88,  89],
#          ...,
#          [ 65,  75,  77, ...,  91,  77,  82],
#          [ 74,  68,  70, ...,  97,  65,  89],
#          [ 75,  72,  66, ...,  92,  94,  98]], dtype=uint8),
#   0],
#  [array([[174, 172, 171, ..., 184, 183, 183],
#          [173, 172, 172, ..., 184, 183, 183],
#          [175, 173, 173, ..., 184, 184, 182],
#          ...,
#          [183, 185, 183, ..., 159, 154, 153],
#          [186, 186, 190, ..., 158, 165, 159],
#          [185, 191, 185, ..., 160, 158, 157]], dtype=uint8),
#   0],
#  [array([[ 53,  58,  61, ..., 112, 170, 183],
#          [ 61,  59,  69, ..., 173, 133, 137],
#          [ 52,  59,  62, ..., 140, 194, 167],
#          ...,
#          [ 65,  64,  67, ..., 163, 191, 247],
#          [ 75,  65,  62, ..., 159, 167, 177],
# ...
#          ...,
#          [153,  35, 107, ...,  28,  28,  38],
#          [ 66,  75, 135, ..., 116, 152,  30],
#          [156, 145, 119, ...,  60,  22,  39]], dtype=uint8),
#   0],
#  [array([[129, 135, 135, ..., 116, 112, 109],
#          [130, 136, 142, ..., 119, 114, 113],
#          [132, 133, 134, ..., 120, 116, 113],
#          ...,
#          [113, 118, 123, ..., 116, 114, 114],
#          [ 85,  91,  92, ..., 117, 116, 116],
#          [211, 212, 213, ..., 210, 210, 205]], dtype=uint8),
#   0],
#  [array([[123, 132, 134, ...,  20,  82,  78],
#          [136, 146, 145, ...,  12,  16,  29],
#          [151, 154, 126, ...,   3,   5,   6],
#          ...,
#          [ 80,  76,  76, ...,  56,  56,  41],
#          [ 75,  78,  81, ...,  59,  55,  47],
#          [ 74,  73,  77, ...,  53,  48,  49]], dtype=uint8),
#   0],
#  [array([[ 81,  73,  60, ..., 121, 126, 146],
#          [ 79,  66,  59, ..., 124, 121, 152],
#          [ 82,  71,  63, ...,  99, 123, 145],
#          ...,
#          [125, 123, 116, ...,  84,  83,  77],
#          [163, 167, 161, ..., 177, 109, 139],
#          [166, 167, 160, ...,  83, 128, 139]], dtype=uint8),
#   0],
#  [array([[202, 164,  51, ..., 224, 221, 204],
#          [209, 160,  67, ..., 223, 222, 203],
#          [208, 164,  71, ..., 223, 223, 208],
#          ...,
#          [126, 180, 186, ..., 228, 227, 225],
#          [109, 169, 201, ..., 228, 228, 224],
#          [111, 174, 200, ..., 229, 228, 225]], dtype=uint8),
#   0],
#  [array([[245, 245, 244, ...,  37,  32,  29],
#          [245, 246, 244, ...,  38,  31,  27],
#          [245, 245, 244, ...,  38,  29,  27],
#          ...,
#          [ 37,  24,  19, ...,  38,  26,  24],
#          [ 36,  31,  18, ...,  67,  26,  22],
#          [ 43,  39,  20, ...,  22,  24,  21]], dtype=uint8),
#   0],
#  [array([[25, 20, 16, ..., 57, 34, 36],
#          [25, 21, 17, ..., 65, 59, 58],
#          [20, 25, 17, ..., 60, 73, 49],
#          ...,
#          [22, 19, 15, ..., 57, 27, 62],
#          [38, 29, 20, ..., 42, 51, 24],
#          [12, 20, 17, ..., 47, 55, 43]], dtype=uint8),
#   0],
#  [array([[ 66,  46,  34, ...,  71,  69,  73],
#          [ 67,  27,  66, ...,  73,  73,  74],
#          [ 70,  64,  69, ..., 139, 129, 130],
#          ...,
#          [ 89,  79,  22, ...,  86, 151, 174],
#          [ 66,  56,  28, ..., 110, 154, 159],
#          [107,  67,  30, ...,  95, 169, 119]], dtype=uint8),
#   0],
#  [array([[213, 217, 210, ..., 123, 124, 118],
#          [206, 195, 177, ..., 103, 108, 119],
#          [182, 165, 157, ...,  98, 107, 105],
#          ...,
#          [234, 235, 237, ..., 237, 240, 236],
#          [235, 233, 237, ..., 233, 233, 240],
#          [232, 234, 233, ..., 229, 228, 231]], dtype=uint8),
#   0],
#  [array([[ 88,  93, 113, ..., 215, 225, 239],
#          [ 95,  96, 113, ..., 224, 243, 243],
#          [174, 130, 123, ..., 245, 248, 247],
#          ...,
#          [156, 157, 145, ..., 150, 156, 153],
#          [172, 149, 166, ..., 155, 148, 153],
#          [146, 165, 147, ..., 138, 156, 133]], dtype=uint8),
#   0],
#  [array([[164, 166, 182, ..., 189, 255, 255],
#          [158, 167, 170, ..., 203, 255, 255],
#          [191, 162, 175, ..., 219, 255, 255],
#          ...,
#          [192, 118, 167, ..., 174, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   0],
#  [array([[ 82,  85,  93, ...,  87,  90,  75],
#          [ 87,  91,  88, ..., 104,  93,  87],
#          [ 87,  87,  90, ...,  95, 101,  95],
#          ...,
#          [186, 153, 168, ..., 201, 213, 180],
#          [180, 183, 181, ..., 186, 178, 207],
#          [141, 135, 164, ..., 208, 205, 171]], dtype=uint8),
#   0],
#  [array([[132, 166, 147, ..., 130, 130, 117],
#          [148, 188, 162, ..., 100, 117, 101],
#          [153, 172, 161, ..., 145, 131, 142],
#          ...,
#          [148, 131, 136, ..., 149, 103, 122],
#          [117, 159, 130, ..., 145, 131, 162],
#          [ 86, 193, 104, ..., 150,  75, 104]], dtype=uint8),
#   0],
#  [array([[111, 112, 113, ..., 216, 213, 215],
#          [112, 114, 112, ..., 212, 215, 208],
#          [113, 115, 111, ..., 211, 211, 207],
#          ...,
#          [116, 109, 108, ..., 117, 116, 120],
#          [114,  98, 121, ..., 121, 121, 115],
#          [ 86,  98,  90, ..., 114, 115, 104]], dtype=uint8),
#   0],
#  [array([[ 17, 153,  49, ..., 176, 175, 207],
#          [ 23, 145,  55, ..., 175, 170, 246],
#          [ 26, 144,  74, ..., 177, 169, 252],
#          ...,
#          [ 42,  37,  43, ...,  76,  74,  63],
#          [ 31,  52,  66, ...,  71,  73,  66],
#          [ 52,  58,  48, ...,  74,  72,  62]], dtype=uint8),
#   0],
#  [array([[  9,  14,  18, ..., 122, 120, 123],
#          [ 19,  20,  22, ..., 120, 128, 109],
#          [  8,   8,  17, ..., 120, 206, 246],
#          ...,
#          [209, 199, 190, ..., 198, 179, 221],
#          [181, 193, 220, ..., 219, 192, 153],
#          [196, 185, 205, ..., 202, 185, 211]], dtype=uint8),
#   0],
#  [array([[131, 134, 110, ..., 119, 133, 126],
#          [144, 140, 143, ..., 126, 134, 136],
#          [142, 144, 131, ..., 132, 134, 135],
#          ...,
#          [167, 174, 171, ..., 158, 106, 112],
#          [155, 171, 166, ...,  68, 144, 152],
#          [ 93, 177, 128, ..., 128,  87,  67]], dtype=uint8),
#   0],
#  [array([[ 74,  90,  75, ...,  88, 132,  81],
#          [ 58,  89,  86, ...,  75, 168,  77],
#          [ 45,  81,  81, ...,  76, 159, 117],
#          ...,
#          [ 91, 176, 102, ..., 214, 210,  97],
#          [128,  76,  88, ..., 209, 208,  96],
#          [105, 108,  67, ..., 183, 203,  99]], dtype=uint8),
#   0],
#  [array([[144, 112, 112, ..., 152, 105, 127],
#          [109, 115, 101, ..., 117, 102, 110],
#          [106, 120,  94, ..., 105,  92, 122],
#          ...,
#          [151, 103,  80, ..., 130, 112, 113],
#          [152, 103,  91, ..., 133, 108, 108],
#          [161,  98,  85, ..., 101, 111, 107]], dtype=uint8),
#   0],
#  [array([[151, 152, 149, ..., 147, 146, 145],
#          [155, 152, 154, ..., 143, 146, 144],
#          [149, 151, 151, ..., 146, 146, 146],
#          ...,
#          [  8,   5,  13, ...,  11,  10,  12],
#          [ 23,  24,  25, ...,  12,  12,  12],
#          [ 12,  16,  16, ...,   9,   9,  12]], dtype=uint8),
#   0],
#  [array([[118, 133, 125, ..., 185, 187, 184],
#          [148, 119, 141, ..., 187, 184, 186],
#          [140, 128, 131, ..., 186, 186, 184],
#          ...,
#          [236, 230, 221, ..., 145, 147, 152],
#          [239, 222, 228, ..., 155, 155, 149],
#          [177, 198, 229, ..., 160, 155, 150]], dtype=uint8),
#   0],
#  [array([[39, 32, 19, ..., 38, 27, 24],
#          [33, 32, 18, ..., 43, 32, 19],
#          [35, 35, 20, ..., 45, 34, 24],
#          ...,
#          [80, 78, 84, ..., 62, 55, 46],
#          [79, 61, 61, ..., 73, 74, 42],
#          [53, 53, 60, ..., 70, 74, 67]], dtype=uint8),
#   0],
#  [array([[222, 214, 124, ..., 254, 255, 255],
#          [243, 168, 217, ..., 248, 253, 253],
#          [240, 179, 239, ..., 199, 201, 201],
#          ...,
#          [ 94,  85,  96, ..., 113, 115, 106],
#          [ 99,  87, 100, ...,  95,  77,  82],
#          [110, 102,  94, ..., 101, 129, 102]], dtype=uint8),
#   0],
#  [array([[240, 249, 244, ..., 155, 130, 145],
#          [242, 247, 244, ..., 179, 172, 146],
#          [244, 248, 244, ..., 172, 186, 167],
#          ...,
#          [ 91, 112,  68, ..., 142, 117, 144],
#          [113, 176, 158, ...,  74,  90, 132],
#          [ 81, 142, 127, ..., 123, 101, 103]], dtype=uint8),
#   0],
#  [array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   0],
#  [array([[242, 246, 240, ...,  26,   4,  26],
#          [241, 245, 241, ...,  34,  16,   2],
#          [243, 246, 245, ...,  23,  37,  30],
#          ...,
#          [ 75,  66,  34, ...,  72, 123, 113],
#          [ 37,  52, 106, ...,  49, 137,  76],
#          [100,  67,  88, ...,  79, 130, 126]], dtype=uint8),
#   0],
#  [array([[ 15,  11,  13, ...,  44,  36,  37],
#          [ 12,  13,   6, ...,  50,  34,  34],
#          [ 15,  12,  14, ...,  45,  43,  35],
#          ...,
#          [146, 172, 147, ...,  67,  81,  53],
#          [107, 159, 153, ...,  76,  56, 119],
#          [ 94, 166, 181, ...,  69,  57,  45]], dtype=uint8),
#   0],
#  [array([[251, 251, 251, ...,  95,  77,  71],
#          [251, 251, 251, ...,  64,  74,  66],
#          [251, 251, 251, ...,  57,  73,  66],
#          ...,
#          [136, 111,  46, ...,  86,  96, 107],
#          [121, 114, 116, ...,  93,  94,  64],
#          [ 54,  66,  83, ...,  47,  93, 147]], dtype=uint8),
#   0],
#  [array([[ 86,  72,  69, ...,  87,  66,  55],
#          [ 77,  71,  65, ...,  99,  92,  81],
#          [ 66,  59,  64, ...,  94,  91, 113],
#          ...,
#          [140, 146, 178, ...,  67, 124, 129],
#          [149, 202, 129, ...,  96, 134, 111],
#          [199, 156, 100, ..., 145, 108,  89]], dtype=uint8),
#   0],
#  [array([[ 41,  41,  47, ...,  48,  72,  27],
#          [ 32,  33,  30, ...,  32,  68,  18],
#          [ 98, 110, 133, ...,  28,  34,  28],
#          ...,
#          [199, 114, 144, ..., 215, 220, 212],
#          [199, 142, 169, ..., 207, 155, 150],
#          [205, 167, 146, ..., 211, 212, 215]], dtype=uint8),
#   0],
#  [array([[158, 160, 159, ..., 137, 127, 121],
#          [161, 157, 156, ..., 142, 122, 130],
#          [156, 151, 158, ..., 136, 132, 119],
#          ...,
#          [ 41,  46,  69, ...,  49,  63,  45],
#          [ 44,  51,  49, ...,  53,  59,  50],
#          [ 48,  39,  44, ...,  53,  57,  61]], dtype=uint8),
#   0],
#  [array([[156, 156, 157, ..., 216, 217, 217],
#          [160, 162, 163, ..., 216, 217, 216],
#          [175, 174, 177, ..., 216, 214, 217],
#          ...,
#          [220, 220, 217, ..., 117,  98, 102],
#          [220, 220, 217, ..., 115, 102, 103],
#          [219, 218, 218, ..., 104, 110, 103]], dtype=uint8),
#   0],
#  [array([[201, 201, 200, ..., 182, 179, 176],
#          [199, 200, 202, ..., 179, 172, 173],
#          [199, 200, 199, ..., 177, 177, 171],
#          ...,
#          [211, 231, 252, ..., 160, 167, 186],
#          [234, 212, 230, ..., 170, 167, 166],
#          [231, 228, 230, ..., 177, 171, 167]], dtype=uint8),
#   0],
#  [array([[ 95,  67,  27, ..., 190, 174, 202],
#          [ 29,  32, 107, ..., 186, 210, 211],
#          [ 62,  62,  43, ..., 187, 215, 213],
#          ...,
#          [164, 108, 189, ...,  41, 171, 179],
#          [180, 175, 182, ...,  44,  57, 165],
#          [185, 184, 165, ...,  47,  45,  49]], dtype=uint8),
#   0],
#  [array([[161, 160, 158, ..., 154, 156, 149],
#          [161, 162, 158, ..., 153, 155, 148],
#          [ 82,  90,  88, ..., 151, 151, 153],
#          ...,
#          [178, 184, 171, ..., 155, 181, 183],
#          [170, 162, 164, ..., 147, 176, 180],
#          [173, 161, 169, ..., 145, 152, 184]], dtype=uint8),
#   0],
#  [array([[138, 126, 129, ...,  61,  89,  73],
#          [131, 126, 129, ...,  63, 104,  73],
#          [133, 128, 124, ...,  66, 102,  69],
#          ...,
#          [222, 227, 207, ...,  55,  39,  70],
#          [220, 235, 230, ...,  30,  39,  71],
#          [229, 220, 173, ...,  55,  41,  74]], dtype=uint8),
#   0],
#  [array([[220, 224, 223, ..., 224, 224, 186],
#          [222, 216, 213, ..., 226, 220, 183],
#          [203, 203, 222, ..., 221, 218, 183],
#          ...,
#          [ 56,  62,  79, ..., 242, 186, 116],
#          [ 51,  49,  45, ..., 248, 244, 103],
#          [ 66,  80,  67, ..., 250, 204, 155]], dtype=uint8),
#   0],
#  [array([[255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          ...,
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255],
#          [255, 255, 255, ..., 255, 255, 255]], dtype=uint8),
#   0],
#  [array([[231, 233, 233, ..., 233, 234, 233],
#          [232,  14,  18, ...,  19,  43, 234],
#          [232,  25,  30, ...,  41,  41, 234],
#          ...,
#          [233, 239, 235, ...,  38,  36, 232],
#          [234, 231, 229, ...,  36,  35, 231],
#          [235, 233, 233, ..., 233, 232, 232]], dtype=uint8),
#   0],
#  [array([[250, 249, 250, ..., 250, 250, 250],
#          [251, 252, 251, ..., 250, 250, 251],
#          [249, 248, 246, ..., 250, 250, 248],
#          ...,
#          [211, 206, 201, ...,  53,  59,  58],
#          [215, 206, 200, ...,  57,  64,  70],
#          [220, 213, 208, ...,  56,  63,  59]], dtype=uint8),
#   0],
#  [array([[ 69,  61,  52, ..., 114, 114, 114],
#          [ 71,  56,  57, ..., 116, 122, 117],
#          [ 62,  49,  53, ..., 116, 115, 109],
#          ...,
#          [ 70,  61,  83, ...,  87, 103,  86],
#          [ 63,  75,  71, ...,  80,  94,  84],
#          [ 62,  63,  81, ...,  81,  93,  88]], dtype=uint8),
#   0],
#  [array([[ 75,  83, 111, ...,  58,  59,  65],
#          [ 77,  78, 108, ...,  58,  63,  76],
#          [ 76,  80,  88, ...,  55,  62,  74],
#          ...,
#          [ 55,  50,  23, ..., 135, 137, 131],
#          [ 23,  39,  51, ..., 141, 137, 134],
#          [ 19,  31, 111, ..., 141, 144, 136]], dtype=uint8),
#   0],
#  [array([[248, 250, 250, ..., 154, 144, 157],
#          [250, 250, 250, ..., 157, 154, 150],
#          [250, 250, 250, ..., 161, 157, 150],
#          ...,
#          [250, 250, 248, ..., 128, 111,  96],
#          [251, 251, 251, ..., 125, 102,  97],
#          [250, 251, 250, ..., 123, 109,  94]], dtype=uint8),
#   0],
#  [array([[134, 133, 135, ...,  96,  78,  82],
#          [191, 197, 197, ...,  68,  65,  55],
#          [196, 198, 201, ...,  71,  66,  61],
#          ...,
#          [ 72, 108, 107, ...,  86,  81,  96],
#          [ 80,  67,  29, ..., 137,  73, 110],
#          [ 44,  49,  39, ..., 103, 115,  77]], dtype=uint8),
#   0],
#  [array([[ 15,  22,  49, ..., 120, 164, 172],
#          [ 13,  44,  90, ...,  77, 167, 171],
#          [ 57,  55,  61, ...,  46, 158, 172],
#          ...,
#          [188, 183, 178, ..., 142, 138, 155],
#          [171, 167, 163, ..., 146, 138, 140],
#          [145, 150, 154, ..., 147, 146, 140]], dtype=uint8),
#   0],
#  [array([[153, 158, 137, ..., 225, 225, 225],
#          [127, 131, 122, ..., 223, 221, 219],
#          [110, 127, 129, ..., 226, 225, 225],
#          ...,
#          [ 80,  95, 124, ..., 191, 196, 198],
#          [117,  76, 137, ..., 192, 197, 191],
#          [ 76,  94, 106, ..., 193, 190, 195]], dtype=uint8),
#   0],
#  [array([[ 86, 109,  86, ..., 137, 132, 131],
#          [122, 127, 144, ..., 144, 136, 128],
#          [ 93, 113, 115, ..., 172, 138, 149],
#          ...,
#          [126, 120, 132, ...,  62,  83,  61],
#          [ 61,  71,  94, ...,  82,  61,  67],
#          [ 24,  90,  56, ...,  47,  60,  69]], dtype=uint8),
#   0],
#  [array([[181, 182, 184, ..., 254, 147, 174],
#          [182, 184, 182, ..., 253, 102, 151],
#          [183, 182, 184, ..., 249, 152, 157],
#          ...,
#          [ 67,  72,  67, ..., 138,  69,  37],
#          [ 65,  67,  71, ...,  88,  49,  36],
#          [ 66,  72,  73, ...,  40,  41,  34]], dtype=uint8),
#   0],
#  [array([[205, 202, 209, ..., 149, 149, 149],
#          [203, 206, 210, ..., 104, 107, 109],
#          [219, 222, 227, ...,  84,  77,  76],
#          ...,
#          [251, 254, 255, ..., 178, 207, 224],
#          [252, 254, 255, ..., 193, 220, 217],
#          [253, 254, 255, ..., 198, 212, 184]], dtype=uint8),
#   0],
#  [array([[157, 157, 103, ...,  67,  59,  51],
#          [157, 159,  98, ...,  63,  65,  54],
#          [160, 157,  99, ...,  62,  45,  34],
#          ...,
#          [181, 170, 176, ..., 210, 216, 222],
#          [179, 182, 192, ..., 220, 211, 215],
#          [190, 190, 199, ..., 213, 197, 202]], dtype=uint8),
#   0],
#  [array([[ 89,  94,  94, ...,  34,  40,  22],
#          [ 91,  95, 108, ...,  13,   9,  37],
#          [ 91,  91,  94, ...,  65,  65,  54],
#          ...,
#          [ 91, 153, 160, ...,  67,  66,  65],
#          [ 99, 164, 156, ...,  65,  65,  64],
#          [ 88,  92, 147, ...,  63,  64,  62]], dtype=uint8),
#   0],
#  [array([[254, 255, 132, ..., 244, 239, 236],
#          [252, 251, 146, ..., 137, 141, 158],
#          [252, 250, 136, ..., 152, 169, 173],
#          ...,
#          [242,  83,  72, ...,  65,  67, 224],
#          [244,  83,  78, ...,  69,  64, 223],
#          [247, 112, 110, ...,  62, 104, 224]], dtype=uint8),
#   0],
#  ...]

# %%
path_X = "data/X.pickle"
path_y = "data/y.pickle"
save_data(training_data, path_X, path_y)

# %%
training_data[0][0].shape
# Out:
# (50, 50)
